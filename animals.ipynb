# %%
import pandas as pd
data = pd.read_csv( 'seattle_pet_licenses.csv', delimiter = ',') 
data
# Out:
#       animal_s_name       license_issue_date  license_number  \
# 0              Ozzy  2005-03-29T00:00:00.000        130651.0
# 1              Jack  2009-12-23T00:00:00.000        898148.0
# 2            Ginger  2006-01-20T00:00:00.000         29654.0
# 3            Pepper  2006-02-07T00:00:00.000         75432.0
# 4              Addy  2006-08-04T00:00:00.000        729899.0
# ...             ...                      ...             ...
# 66037          Lily  2016-12-27T00:00:00.000             NaN
# 66038         Ellie  2016-11-29T00:00:00.000             NaN
# 66039         Sammy  2016-12-05T00:00:00.000             NaN
# 66040         Buddy  2016-12-06T00:00:00.000             NaN
# 66041           Aku  2016-12-07T00:00:00.000             NaN
#
#                            primary_breed      secondary_breed species zip_code
# 0      Dachshund, Standard Smooth Haired                  NaN     Dog    98104
# ...

# %%
dogs=data[data['species']=='Dog']
dogs
# Out:
#       animal_s_name       license_issue_date  license_number  \
# 0              Ozzy  2005-03-29T00:00:00.000        130651.0
# 1              Jack  2009-12-23T00:00:00.000        898148.0
# 2            Ginger  2006-01-20T00:00:00.000         29654.0
# 4              Addy  2006-08-04T00:00:00.000        729899.0
# 5            Rustie  2007-07-24T00:00:00.000        437433.0
# ...             ...                      ...             ...
# 66031        Bonita  2016-12-22T00:00:00.000             NaN
# 66038         Ellie  2016-11-29T00:00:00.000             NaN
# 66039         Sammy  2016-12-05T00:00:00.000             NaN
# 66040         Buddy  2016-12-06T00:00:00.000             NaN
# 66041           Aku  2016-12-07T00:00:00.000             NaN
#
#                            primary_breed      secondary_breed species zip_code
# 0      Dachshund, Standard Smooth Haired                  NaN     Dog    98104
# ...

# %%
cats=data[data['species']=='Cat']
cats
# Out:
#       animal_s_name       license_issue_date  license_number  \
# 3            Pepper  2006-02-07T00:00:00.000         75432.0
# 7             Emily  2007-11-19T00:00:00.000        895915.0
# 14           Hunter  2008-08-02T00:00:00.000        352920.0
# 32           Skyler  2011-03-28T00:00:00.000        134722.0
# 42     Mister Kitty  2012-02-10T00:00:00.000         81952.0
# ...             ...                      ...             ...
# 66033           boy  2016-11-25T00:00:00.000             NaN
# 66034           NaN  2016-11-25T00:00:00.000             NaN
# 66035           NaN  2016-11-25T00:00:00.000             NaN
# 66036           NaN  2016-11-26T00:00:00.000             NaN
# 66037          Lily  2016-12-27T00:00:00.000             NaN
#
#               primary_breed secondary_breed species zip_code
# 3                      Manx             Mix     Cat    98103
# 7      Domestic Medium Hair             NaN     Cat    98103
# ...

# %%
livestock=data[data['species']=='Livestock']
livestock
# Out:
#                 animal_s_name       license_issue_date  license_number  \
# 10643                  Eloise  2015-06-05T00:00:00.000        214413.0
# 10718                   Holly  2015-05-12T00:00:00.000        282091.0
# 10719               Priscilla  2015-05-12T00:00:00.000        282092.0
# 19653                 Phyllis  2015-07-11T00:00:00.000        432423.0
# 19654                   Rosie  2015-07-11T00:00:00.000        432424.0
# 20377                 Pegasis  2015-12-01T00:00:00.000        828693.0
# 20410                  Amanda  2015-12-01T00:00:00.000        828692.0
# 20786                 Abelard  2015-07-31T00:00:00.000        443495.0
# 24122                   Minty  2015-10-05T00:00:00.000        834015.0
# 24230                  Moppet  2015-12-01T00:00:00.000        903797.0
# 25087                   Willi  2015-10-05T00:00:00.000        834013.0
# 26376                   Olive  2015-07-31T00:00:00.000        443496.0
# ...

# %%
species= data['species'].value_counts()
species
# Out:
# Dog          43076
# Cat          22915
# Livestock       51
# Name: species, dtype: int64

# %%
import matplotlib.pyplot as plt
species.plot.pie()
# Out:
# <AxesSubplot:ylabel='species'>

# %%
species.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
dogs_pp=dogs['primary_breed'].value_counts()
dogs_pp
# Out:
# Retriever, Labrador           6350
# Retriever, Golden             2321
# Chihuahua, Short Coat         2134
# German Shepherd               1259
# Australian Shepherd           1184
#                               ...
# Terrier, Skye                    1
# Terrier, American Hairless       1
# Braque Francais Gascogne         1
# Maremma Sheepdog                 1
# Azores Cattle Dog                1
# Name: primary_breed, Length: 267, dtype: int64

# %%
dogs_pp.plot.pie()
# Out:
# <AxesSubplot:ylabel='primary_breed'>

# %%
dogs_sp=dogs['secondary_breed'].value_counts()
dogs_sp
# Out:
# Mix                     5478
# Poodle, Standard        1241
# Poodle, Miniature       1059
# Retriever, Labrador     1034
# Terrier                  485
#                         ...
# Alaskan Klee Kai           1
# German Pinscher            1
# Norwegian Buhund           1
# Spaniel, Boykin            1
# Spaniel, English Toy       1
# Name: secondary_breed, Length: 199, dtype: int64

# %%
data[data['secondary_breed']=='Terrier']
# Out:
#       animal_s_name       license_issue_date  license_number  \
# 188           Yoshi  2013-11-14T00:00:00.000        902842.0
# 380           Yoshi  2013-11-14T00:00:00.000        902842.0
# 636          Gracie  2014-05-16T00:00:00.000        213897.0
# 695           Sally  2014-04-21T00:00:00.000         83598.0
# 1922          Rocky  2014-12-18T00:00:00.000        960997.0
# ...             ...                      ...             ...
# 65684          Juno  2016-12-13T00:00:00.000             NaN
# 65823         Olive  2016-12-20T00:00:00.000             NaN
# 65871        Casper  2016-12-22T00:00:00.000             NaN
# 65959        Thomas  2016-12-28T00:00:00.000             NaN
# 66041           Aku  2016-12-07T00:00:00.000             NaN
#
#                primary_breed secondary_breed species zip_code
# 188              Poodle, Toy         Terrier     Dog    98118
# 380              Poodle, Toy         Terrier     Dog    98118
# ...

# %%
jack = data[data['animal_s_name']=='Jack']
jack
# Out:
#       animal_s_name       license_issue_date  license_number  \
# 1              Jack  2009-12-23T00:00:00.000        898148.0
# 57             Jack  2013-05-17T00:00:00.000        276549.0
# 202            Jack  2013-08-06T00:00:00.000         82624.0
# 249            Jack  2013-05-17T00:00:00.000        276549.0
# 394            Jack  2013-08-06T00:00:00.000         82624.0
# ...             ...                      ...             ...
# 64760          Jack  2016-12-13T00:00:00.000        954182.0
# 64877          Jack  2016-12-27T00:00:00.000             NaN
# 64940          Jack  2016-12-08T00:00:00.000             NaN
# 65775          Jack  2016-12-19T00:00:00.000             NaN
# 65783          Jack  2016-12-20T00:00:00.000             NaN
#
#               primary_breed      secondary_breed species zip_code
# 1      Schnauzer, Miniature         Terrier, Rat     Dog    98107
# 57     Domestic Medium Hair                  NaN     Cat    98118
# ...

# %%
jack['species'].value_counts()
# Out:
# Dog    215
# Cat     87
# Name: species, dtype: int64

# %%
data[data['license_issue_date']=='2016-12-06T00:00:00.000']
# Out:
#       animal_s_name       license_issue_date  license_number  \
# 63044         Jonie  2016-12-06T00:00:00.000        732704.0
# 63048    Miss Kitty  2016-12-06T00:00:00.000        897493.0
# 63059           NaN  2016-12-06T00:00:00.000        891617.0
# 63092          Zoey  2016-12-06T00:00:00.000        904477.0
# 63209        Bailey  2016-12-06T00:00:00.000        902459.0
# ...             ...                      ...             ...
# 65525          Star  2016-12-06T00:00:00.000             NaN
# 65526          Kona  2016-12-06T00:00:00.000             NaN
# 65527         Henry  2016-12-06T00:00:00.000             NaN
# 65528          Maya  2016-12-06T00:00:00.000             NaN
# 66040         Buddy  2016-12-06T00:00:00.000             NaN
#
#              primary_breed secondary_breed species zip_code
# 63044    Domestic Longhair             NaN     Cat    98117
# 63048   Domestic Shorthair             NaN     Cat    98199
# ...

# %%
# Out:
# animal_s_name         NaN
# license_issue_date    NaN
# license_number        NaN
# primary_breed         NaN
# secondary_breed       NaN
# species               NaN
# zip_code              NaN
# dtype: object
